# %% [markdown]
# # Make sure your Config File is set!!

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (1.25.10)

# %%
import requests 
import datetime
import base64
from urllib.parse import urlencode

# from config import client_id
# from config import client_secret

client_id = "61571ab2d97c41c79ef2c934842244f6"
client_secret = "13573e14e35c4a3ea20a280c0e9f49ae"

# %%
class SpotifyAPI(object):
    access_token = None 
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None 
    client_secret = None 
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        Returns a base 64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type" : "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data = token_data, headers = token_headers)
        if r.status_code not in range(200, 299): 
            return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds 
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
access_token = spotify.access_token

# %%
### BROWSE API - NEW RELEASES

headers = {
    "Authorization" : f"Bearer {access_token}"
}

endpoint = "https://api.spotify.com/v1/browse/new-releases?"

data = urlencode({"limit":50})

lookup_url = f"{endpoint}{data}"

response = requests.get(lookup_url, headers=headers).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "albums": {
#         "href": "https://api.spotify.com/v1/browse/new-releases?offset=0&limit=50",
#         "items": [
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s",
#                         "id": "1uNFoZAHBGtllmzznpCI3s",
#                         "name": "Justin Bieber",
#                         "type": "artist",
#                         "uri": "spotify:artist:1uNFoZAHBGtllmzznpCI3s"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5CiGnKThu5ctn9pBxv7DGa"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5CiGnKThu5ctn9pBxv7DGa",
#                         "id": "5CiGnKThu5ctn9pBxv7DGa",
#                         "name": "benny blanco",
#                         "type": "artist",
#                         "uri": "spotify:artist:5CiGnKThu5ctn9pBxv7DGa"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3P5WIUJO0Ots1lQx09TOxk"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3P5WIUJO0Ots1lQx09TOxk",
#                 "id": "3P5WIUJO0Ots1lQx09TOxk",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b27383b22beb73e2014b20159685",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e0283b22beb73e2014b20159685",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d0000485183b22beb73e2014b20159685",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Lonely (with benny blanco)",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:3P5WIUJO0Ots1lQx09TOxk"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5JZ7CnR6gTvEMKX4g70Amv"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5JZ7CnR6gTvEMKX4g70Amv",
#                         "id": "5JZ7CnR6gTvEMKX4g70Amv",
#                         "name": "Lauv",
#                         "type": "artist",
#                         "uri": "spotify:artist:5JZ7CnR6gTvEMKX4g70Amv"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/4Uc8Dsxct0oMqx0P6i60ea"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/4Uc8Dsxct0oMqx0P6i60ea",
#                         "id": "4Uc8Dsxct0oMqx0P6i60ea",
#                         "name": "Conan Gray",
#                         "type": "artist",
#                         "uri": "spotify:artist:4Uc8Dsxct0oMqx0P6i60ea"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/6pbBHbkfs6i0JzhWjDmvb1"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/6pbBHbkfs6i0JzhWjDmvb1",
#                 "id": "6pbBHbkfs6i0JzhWjDmvb1",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2737eff443a62c51d7f9d39dc20",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e027eff443a62c51d7f9d39dc20",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048517eff443a62c51d7f9d39dc20",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Fake",
#                 "release_date": "2020-10-13",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:6pbBHbkfs6i0JzhWjDmvb1"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/7c0XG5cIJTrrAgEC3ULPiq"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq",
#                         "id": "7c0XG5cIJTrrAgEC3ULPiq",
#                         "name": "Ty Dolla $ign",
#                         "type": "artist",
#                         "uri": "spotify:artist:7c0XG5cIJTrrAgEC3ULPiq"
#                     },
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5ZS223C6JyBfXasXxrRqOk"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5ZS223C6JyBfXasXxrRqOk",
#                         "id": "5ZS223C6JyBfXasXxrRqOk",
#                         "name": "Jhen\u00e9 Aiko",
#                         "type": "artist",
#                         "uri": "spotify:artist:5ZS223C6JyBfXasXxrRqOk"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/1CQFYWHVdRypCsU2IU80t1"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/1CQFYWHVdRypCsU2IU80t1",
#                 "id": "1CQFYWHVdRypCsU2IU80t1",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273c58569972ae7fdbeacc4606b",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02c58569972ae7fdbeacc4606b",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851c58569972ae7fdbeacc4606b",
#                         "width": 64
#                     }
#                 ],
#                 "name": "By Yourself (feat. Jhen\u00e9 Aiko & Mustard)",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:1CQFYWHVdRypCsU2IU80t1"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/35l9BRT7MXmM8bv2WDQiyB"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/35l9BRT7MXmM8bv2WDQiyB",
#                         "id": "35l9BRT7MXmM8bv2WDQiyB",
#                         "name": "beabadoobee",
#                         "type": "artist",
#                         "uri": "spotify:artist:35l9BRT7MXmM8bv2WDQiyB"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3SGFxGF2loXeOFZtKvdmxo"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3SGFxGF2loXeOFZtKvdmxo",
#                 "id": "3SGFxGF2loXeOFZtKvdmxo",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273942201cac6bfe1367b017286",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02942201cac6bfe1367b017286",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851942201cac6bfe1367b017286",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Fake It Flowers",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 12,
#                 "type": "album",
#                 "uri": "spotify:album:3SGFxGF2loXeOFZtKvdmxo"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/53KwLdlmrlCelAZMaLVZqU"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/53KwLdlmrlCelAZMaLVZqU",
#                         "id": "53KwLdlmrlCelAZMaLVZqU",
#                         "name": "James Blake",
#                         "type": "artist",
#                         "uri": "spotify:artist:53KwLdlmrlCelAZMaLVZqU"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/5vqILcEeCT0N1DeJBsLrGE"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/5vqILcEeCT0N1DeJBsLrGE",
#                 "id": "5vqILcEeCT0N1DeJBsLrGE",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273bd24006fb195e4eba9b21ccc",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02bd24006fb195e4eba9b21ccc",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851bd24006fb195e4eba9b21ccc",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Before",
#                 "release_date": "2020-10-14",
#                 "release_date_precision": "day",
#                 "total_tracks": 4,
#                 "type": "album",
#                 "uri": "spotify:album:5vqILcEeCT0N1DeJBsLrGE"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/0eDvMgVFoNV3TpwtrVCoTj"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/0eDvMgVFoNV3TpwtrVCoTj",
#                         "id": "0eDvMgVFoNV3TpwtrVCoTj",
#                         "name": "Pop Smoke",
#                         "type": "artist",
#                         "uri": "spotify:artist:0eDvMgVFoNV3TpwtrVCoTj"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/76ME7LgGQq5fuTy9wWBHpq"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/76ME7LgGQq5fuTy9wWBHpq",
#                 "id": "76ME7LgGQq5fuTy9wWBHpq",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b27344ef06f98bf4c5db0c5ee2a6",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e0244ef06f98bf4c5db0c5ee2a6",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d0000485144ef06f98bf4c5db0c5ee2a6",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Iced Out Audemars (Remix)",
#                 "release_date": "2020-10-15",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:76ME7LgGQq5fuTy9wWBHpq"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/6fOMl44jA4Sp5b9PpYCkzz"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/6fOMl44jA4Sp5b9PpYCkzz",
#                         "id": "6fOMl44jA4Sp5b9PpYCkzz",
#                         "name": "NF",
#                         "type": "artist",
#                         "uri": "spotify:artist:6fOMl44jA4Sp5b9PpYCkzz"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/1wo8JeDRslm23n6rqpb3jk"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/1wo8JeDRslm23n6rqpb3jk",
#                 "id": "1wo8JeDRslm23n6rqpb3jk",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2739ad2960fafd7b9656c895578",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e029ad2960fafd7b9656c895578",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048519ad2960fafd7b9656c895578",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Chasing_(Demo)",
#                 "release_date": "2020-10-12",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:1wo8JeDRslm23n6rqpb3jk"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/2UZMlIwnkgAEDBsw1Rejkn"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/2UZMlIwnkgAEDBsw1Rejkn",
#                         "id": "2UZMlIwnkgAEDBsw1Rejkn",
#                         "name": "Tom Petty",
#                         "type": "artist",
#                         "uri": "spotify:artist:2UZMlIwnkgAEDBsw1Rejkn"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/2s7jw1QyMFXe1fsSzla8cv"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/2s7jw1QyMFXe1fsSzla8cv",
#                 "id": "2s7jw1QyMFXe1fsSzla8cv",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2731fcdc6d32cd75731456cbf48",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e021fcdc6d32cd75731456cbf48",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048511fcdc6d32cd75731456cbf48",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Wildflowers & All The Rest (Deluxe Edition)",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 54,
#                 "type": "album",
#                 "uri": "spotify:album:2s7jw1QyMFXe1fsSzla8cv"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/4xnihxcoXWK3UqryOSnbw5"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/4xnihxcoXWK3UqryOSnbw5",
#                         "id": "4xnihxcoXWK3UqryOSnbw5",
#                         "name": "Sasha Sloan",
#                         "type": "artist",
#                         "uri": "spotify:artist:4xnihxcoXWK3UqryOSnbw5"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/7v0KN0VlHJZrhAbSbxEZvZ"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/7v0KN0VlHJZrhAbSbxEZvZ",
#                 "id": "7v0KN0VlHJZrhAbSbxEZvZ",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2731e4429a14d693b418b198056",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e021e4429a14d693b418b198056",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048511e4429a14d693b418b198056",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Only Child",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 10,
#                 "type": "album",
#                 "uri": "spotify:album:7v0KN0VlHJZrhAbSbxEZvZ"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO",
#                         "id": "5FxD8fkQZ6KcsSYupDVoSO",
#                         "name": "Omar Apollo",
#                         "type": "artist",
#                         "uri": "spotify:artist:5FxD8fkQZ6KcsSYupDVoSO"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/7HlxxaJOHK0ArY4Ae4Qfc7"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/7HlxxaJOHK0ArY4Ae4Qfc7",
#                 "id": "7HlxxaJOHK0ArY4Ae4Qfc7",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b27373f6df727a4167d26d7b7f45",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e0273f6df727a4167d26d7b7f45",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d0000485173f6df727a4167d26d7b7f45",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Apolonio",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 9,
#                 "type": "album",
#                 "uri": "spotify:album:7HlxxaJOHK0ArY4Ae4Qfc7"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa",
#                         "id": "00FQb4jTyendYWaN8pK0wa",
#                         "name": "Lana Del Rey",
#                         "type": "artist",
#                         "uri": "spotify:artist:00FQb4jTyendYWaN8pK0wa"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
# ...
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3zHgwCgiBWNcXhOX9UrQME"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3zHgwCgiBWNcXhOX9UrQME",
#                 "id": "3zHgwCgiBWNcXhOX9UrQME",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273bc850f0ca2d48ed118b8cf85",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02bc850f0ca2d48ed118b8cf85",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851bc850f0ca2d48ed118b8cf85",
#                         "width": 64
#                     }
#                 ],
#                 "name": "KOV",
#                 "release_date": "2020-10-09",
#                 "release_date_precision": "day",
#                 "total_tracks": 6,
#                 "type": "album",
#                 "uri": "spotify:album:3zHgwCgiBWNcXhOX9UrQME"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/2yJwXpWAQOOl5XFzbCxLs9"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/2yJwXpWAQOOl5XFzbCxLs9",
#                         "id": "2yJwXpWAQOOl5XFzbCxLs9",
#                         "name": "Bad Religion",
#                         "type": "artist",
#                         "uri": "spotify:artist:2yJwXpWAQOOl5XFzbCxLs9"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/4tuKq2JV7r88OLVORQMWKK"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/4tuKq2JV7r88OLVORQMWKK",
#                 "id": "4tuKq2JV7r88OLVORQMWKK",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b273cc157d24bea91d932ed890e7",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e02cc157d24bea91d932ed890e7",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d00004851cc157d24bea91d932ed890e7",
#                         "width": 64
#                     }
#                 ],
#                 "name": "What Are We Standing For",
#                 "release_date": "2020-10-14",
#                 "release_date_precision": "day",
#                 "total_tracks": 1,
#                 "type": "album",
#                 "uri": "spotify:album:4tuKq2JV7r88OLVORQMWKK"
#             },
#             {
#                 "album_type": "single",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/77kULmXAQ6vWer7IIHdGzI"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/77kULmXAQ6vWer7IIHdGzI",
#                         "id": "77kULmXAQ6vWer7IIHdGzI",
#                         "name": "Jordan Davis",
#                         "type": "artist",
#                         "uri": "spotify:artist:77kULmXAQ6vWer7IIHdGzI"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/3roOLsfxMpvsd8cEGJPyrc"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/3roOLsfxMpvsd8cEGJPyrc",
#                 "id": "3roOLsfxMpvsd8cEGJPyrc",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2730f712a886a44291188cab4e3",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e020f712a886a44291188cab4e3",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048510f712a886a44291188cab4e3",
#                         "width": 64
#                     }
#                 ],
#                 "name": "Lose You",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 2,
#                 "type": "album",
#                 "uri": "spotify:album:3roOLsfxMpvsd8cEGJPyrc"
#             },
#             {
#                 "album_type": "album",
#                 "artists": [
#                     {
#                         "external_urls": {
#                             "spotify": "https://open.spotify.com/artist/27CNmUe34ahHuxvayd8Jse"
#                         },
#                         "href": "https://api.spotify.com/v1/artists/27CNmUe34ahHuxvayd8Jse",
#                         "id": "27CNmUe34ahHuxvayd8Jse",
#                         "name": "PRICE",
#                         "type": "artist",
#                         "uri": "spotify:artist:27CNmUe34ahHuxvayd8Jse"
#                     }
#                 ],
#                 "available_markets": [
#                     "AD",
#                     "AE",
#                     "AL",
#                     "AR",
#                     "AT",
#                     "AU",
#                     "BA",
#                     "BE",
#                     "BG",
#                     "BH",
#                     "BO",
#                     "BR",
#                     "BY",
#                     "CA",
#                     "CH",
#                     "CL",
#                     "CO",
#                     "CR",
#                     "CY",
#                     "CZ",
#                     "DE",
#                     "DK",
#                     "DO",
#                     "DZ",
#                     "EC",
#                     "EE",
#                     "EG",
#                     "ES",
#                     "FI",
#                     "FR",
#                     "GB",
#                     "GR",
#                     "GT",
#                     "HK",
#                     "HN",
#                     "HR",
#                     "HU",
#                     "ID",
#                     "IE",
#                     "IL",
#                     "IN",
#                     "IS",
#                     "IT",
#                     "JO",
#                     "JP",
#                     "KW",
#                     "KZ",
#                     "LB",
#                     "LI",
#                     "LT",
#                     "LU",
#                     "LV",
#                     "MA",
#                     "MC",
#                     "MD",
#                     "ME",
#                     "MK",
#                     "MT",
#                     "MX",
#                     "MY",
#                     "NI",
#                     "NL",
#                     "NO",
#                     "NZ",
#                     "OM",
#                     "PA",
#                     "PE",
#                     "PH",
#                     "PL",
#                     "PS",
#                     "PT",
#                     "PY",
#                     "QA",
#                     "RO",
#                     "RS",
#                     "RU",
#                     "SA",
#                     "SE",
#                     "SG",
#                     "SI",
#                     "SK",
#                     "SV",
#                     "TH",
#                     "TN",
#                     "TR",
#                     "TW",
#                     "UA",
#                     "US",
#                     "UY",
#                     "VN",
#                     "XK",
#                     "ZA"
#                 ],
#                 "external_urls": {
#                     "spotify": "https://open.spotify.com/album/1XKhVI0EBWl0xj8liEeB60"
#                 },
#                 "href": "https://api.spotify.com/v1/albums/1XKhVI0EBWl0xj8liEeB60",
#                 "id": "1XKhVI0EBWl0xj8liEeB60",
#                 "images": [
#                     {
#                         "height": 640,
#                         "url": "https://i.scdn.co/image/ab67616d0000b2734a68f12eddf0567d718b07af",
#                         "width": 640
#                     },
#                     {
#                         "height": 300,
#                         "url": "https://i.scdn.co/image/ab67616d00001e024a68f12eddf0567d718b07af",
#                         "width": 300
#                     },
#                     {
#                         "height": 64,
#                         "url": "https://i.scdn.co/image/ab67616d000048514a68f12eddf0567d718b07af",
#                         "width": 64
#                     }
#                 ],
#                 "name": "CLRD.",
#                 "release_date": "2020-10-16",
#                 "release_date_precision": "day",
#                 "total_tracks": 8,
#                 "type": "album",
#                 "uri": "spotify:album:1XKhVI0EBWl0xj8liEeB60"
#             }
#         ],
#         "limit": 50,
#         "next": "https://api.spotify.com/v1/browse/new-releases?offset=50&limit=50",
#         "offset": 0,
#         "previous": null,
#         "total": 100
#     }
# }

# %%
albums = response['albums']['items']

# album_ids = [album['id'] for album in albums]

album_ids = []
artist_ids = []

for album in albums:
    album_ids.append(album['id'])
    
    artists = album['artists']
    
    for artist in artists:
        artist_ids.append(artist['id'])
    
print('*' *50, 'ALBUM IDs are: ', album_ids)
#print('*' *50, 'ARTIST IDs are: ', artist_ids)
# Out:
# ************************************************** ALBUM IDs are:  ['3P5WIUJO0Ots1lQx09TOxk', '6pbBHbkfs6i0JzhWjDmvb1', '1CQFYWHVdRypCsU2IU80t1', '3SGFxGF2loXeOFZtKvdmxo', '5vqILcEeCT0N1DeJBsLrGE', '76ME7LgGQq5fuTy9wWBHpq', '1wo8JeDRslm23n6rqpb3jk', '2s7jw1QyMFXe1fsSzla8cv', '7v0KN0VlHJZrhAbSbxEZvZ', '7HlxxaJOHK0ArY4Ae4Qfc7', '6yEZH1HexM9sqOX34qUE4u', '36Lr1Ipl7w3gn0NdZbRcge', '6wxPYC9LuoJCtKtFw4UDgf', '5tF7JnL3vVYaKap77UUz6p', '2TUgzZ8XOE8jm7tDpU4iME', '2LEEg9PQsJqQuhBU0poSrd', '7e9inFYUpFSKmTFbj2xrCS', '7Myw8J0byMIDilWT9vmZj5', '5EqnUTFVewiWTuN11K4G8E', '6xVP3wpk1yUu8X7zN9gzDW', '4ji352J0NHJfD5gHoJa7Oj', '6OxeYR6XlbyBvYMrUzAfe3', '0rWT19dCpPwXJY2zfaSh5t', '1S6sk9yusYQoadSAbx3ZB8', '35dSb2KjI8u7migJ9AbhqQ', '1KrTC1K1M7kMAMDWlH1coX', '7dKKcOsUPcTrzlQYmG2Hq3', '2RhpPh3aaviygDMbFUa3HG', '3MxrCAA1Z5FOaqdqOaiFYz', '4PuFEbaiovUiX7oMCY4znm', '0FIqCHhKHDqHd35AvRm8gp', '3TmAgHb2Er246whOY5Q3Ft', '6fyg81ZmARpHaxNte8X5NE', '4IgfeLqwtEONvhDTV06UPV', '3PqmfbW9QbYXobJ6qUSfFe', '2HDp9JJaUtB2xU02QGlUif', '71wj7iB4JXxUUTPosOpXMM', '4hHHHg7bYSXH803dEsSyl8', '0MmKsaUxCz8XZrwKoLSFDG', '4BAEubwvC2r7bPRKlmRxUO', '2QFXjy3u6Bl6ctdK9FS9eF', '3OR56niCd9ULFGRhBsZBn3', '2wPKxdAGmxRDbgwF8d6YuY', '0laieZ0AIqtsAFTaljjmLc', '58J1HN0dJl1pkTwu1YGJSq', '5aEqPWv21w8UcfqWnuAN7c', '3zHgwCgiBWNcXhOX9UrQME', '4tuKq2JV7r88OLVORQMWKK', '3roOLsfxMpvsd8cEGJPyrc', '1XKhVI0EBWl0xj8liEeB60']
