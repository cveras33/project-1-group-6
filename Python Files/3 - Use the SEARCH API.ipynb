# %% [markdown]
# # Make sure your Config File is set!!

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/jenniferdean/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages (from requests) (3.0.4)

# %%
import requests 
import datetime
import base64
from urllib.parse import urlencode
from config import client_id
from config import client_secret

client_id = client_id
client_secret = client_secret

# %%
class SpotifyAPI(object):
    access_token = None 
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None 
    client_secret = None 
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        Returns a base 64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type" : "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data = token_data, headers = token_headers)
        if r.status_code not in range(200, 299): 
            return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds 
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
access_token = spotify.access_token

# %%
### SEARCH API


headers = {
    "Authorization" : f"Bearer {access_token}"
}

endpoint = "https://api.spotify.com/v1/search?"
data = urlencode({"q": #Search Keyword,
                  "type": #album , artist, playlist, track, show or episode,
                  "limit" : #How many do you want? (Max50)
                 })

lookup_url = f"{endpoint}{data}"

response = requests.get(lookup_url, headers=headers).json()

response
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=acoustic&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5gw5ANPCVcxU0maLiGRzzP'},
#        'href': 'https://api.spotify.com/v1/artists/5gw5ANPCVcxU0maLiGRzzP',
#        'id': '5gw5ANPCVcxU0maLiGRzzP',
#        'name': 'Billy Raffoul',
#        'type': 'artist',
#        'uri': 'spotify:artist:5gw5ANPCVcxU0maLiGRzzP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Ymsz92GH8H1fS8TLN7HJ0'},
#      'href': 'https://api.spotify.com/v1/albums/4Ymsz92GH8H1fS8TLN7HJ0',
#      'id': '4Ymsz92GH8H1fS8TLN7HJ0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4ab6cd646e9359e07d0004c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4ab6cd646e9359e07d0004c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4ab6cd646e9359e07d0004c',
#        'width': 64}],
#      'name': 'A Few More Hours at YYZ',
#      'release_date': '2020-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:4Ymsz92GH8H1fS8TLN7HJ0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5gw5ANPCVcxU0maLiGRzzP'},
#       'href': 'https://api.spotify.com/v1/artists/5gw5ANPCVcxU0maLiGRzzP',
#       'id': '5gw5ANPCVcxU0maLiGRzzP',
#       'name': 'Billy Raffoul',
#       'type': 'artist',
#       'uri': 'spotify:artist:5gw5ANPCVcxU0maLiGRzzP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 172202,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71802422'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1kJygfS4eoVziBBI93MSYp'},
#     'href': 'https://api.spotify.com/v1/tracks/1kJygfS4eoVziBBI93MSYp',
#     'id': '1kJygfS4eoVziBBI93MSYp',
#     'is_local': False,
#     'name': 'Acoustic',
#     'popularity': 61,
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:1kJygfS4eoVziBBI93MSYp'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#        'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#        'id': '2sil8z5kiy4r76CRTXxBCA',
#        'name': 'The Goo Goo Dolls',
#        'type': 'artist',
#        'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4UMjBXcRqIgMZ1XumU2x5T'},
#      'href': 'https://api.spotify.com/v1/albums/4UMjBXcRqIgMZ1XumU2x5T',
#      'id': '4UMjBXcRqIgMZ1XumU2x5T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eda9478c39a21e1cdc6609ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eda9478c39a21e1cdc6609ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eda9478c39a21e1cdc6609ca',
#        'width': 64}],
#      'name': 'Dizzy up the Girl',
#      'release_date': '1998-09-11',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4UMjBXcRqIgMZ1XumU2x5T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2sil8z5kiy4r76CRTXxBCA'},
#       'href': 'https://api.spotify.com/v1/artists/2sil8z5kiy4r76CRTXxBCA',
#       'id': '2sil8z5kiy4r76CRTXxBCA',
#       'name': 'The Goo Goo Dolls',
#       'type': 'artist',
#       'uri': 'spotify:artist:2sil8z5kiy4r76CRTXxBCA'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 116573,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB19800790'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1RC9slv335IfLce5vt9KTW'},
#     'href': 'https://api.spotify.com/v1/tracks/1RC9slv335IfLce5vt9KTW',
#     'id': '1RC9slv335IfLce5vt9KTW',
#     'is_local': False,
#     'name': 'Acoustic #3',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df7d46edcfbfdca14c33229df8fd9655334acdaf?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:1RC9slv335IfLce5vt9KTW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OMJR0LjjKv21qNvICTgbi'},
#        'href': 'https://api.spotify.com/v1/artists/0OMJR0LjjKv21qNvICTgbi',
#        'id': '0OMJR0LjjKv21qNvICTgbi',
#        'name': 'Devin The Dude',
#        'type': 'artist',
#        'uri': 'spotify:artist:0OMJR0LjjKv21qNvICTgbi'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2stT414iRHEKFBOwGHLyKe'},
#      'href': 'https://api.spotify.com/v1/albums/2stT414iRHEKFBOwGHLyKe',
#      'id': '2stT414iRHEKFBOwGHLyKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dcbc38e70bad75a57e6d5704',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dcbc38e70bad75a57e6d5704',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dcbc38e70bad75a57e6d5704',
#        'width': 64}],
#      'name': 'Acoustic Levitation',
#      'release_date': '2017-03-10',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2stT414iRHEKFBOwGHLyKe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OMJR0LjjKv21qNvICTgbi'},
#       'href': 'https://api.spotify.com/v1/artists/0OMJR0LjjKv21qNvICTgbi',
#       'id': '0OMJR0LjjKv21qNvICTgbi',
#       'name': 'Devin The Dude',
#       'type': 'artist',
#       'uri': 'spotify:artist:0OMJR0LjjKv21qNvICTgbi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 355961,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUYG1131522'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4qsRrKXNKBxZjKWHBrRdXs'},
#     'href': 'https://api.spotify.com/v1/tracks/4qsRrKXNKBxZjKWHBrRdXs',
#     'id': '4qsRrKXNKBxZjKWHBrRdXs',
#     'is_local': False,
#     'name': 'Acoustic Levitation',
#     'popularity': 45,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d4a0f1ff7eb0626eb172581407f67ae06e4ea88a?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4qsRrKXNKBxZjKWHBrRdXs'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ztOXfl03SlHkzRIsrvWmX'},
#        'href': 'https://api.spotify.com/v1/artists/4ztOXfl03SlHkzRIsrvWmX',
#        'id': '4ztOXfl03SlHkzRIsrvWmX',
#        'name': 'Guustavv',
#        'type': 'artist',
#        'uri': 'spotify:artist:4ztOXfl03SlHkzRIsrvWmX'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YCz7aHoRoAZ435UDLOKOs'},
#        'href': 'https://api.spotify.com/v1/artists/2YCz7aHoRoAZ435UDLOKOs',
#        'id': '2YCz7aHoRoAZ435UDLOKOs',
#        'name': 'Justnormal',
#        'type': 'artist',
#        'uri': 'spotify:artist:2YCz7aHoRoAZ435UDLOKOs'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MGL4XU2LCJC47c7VvSwuE'},
#        'href': 'https://api.spotify.com/v1/artists/2MGL4XU2LCJC47c7VvSwuE',
#        'id': '2MGL4XU2LCJC47c7VvSwuE',
#        'name': 'Jobii',
#        'type': 'artist',
#        'uri': 'spotify:artist:2MGL4XU2LCJC47c7VvSwuE'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0YcdHiYam184WYu39rev9k'},
#      'href': 'https://api.spotify.com/v1/albums/0YcdHiYam184WYu39rev9k',
#      'id': '0YcdHiYam184WYu39rev9k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c1d5c3247ff6f9f212a1dc41',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c1d5c3247ff6f9f212a1dc41',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c1d5c3247ff6f9f212a1dc41',
#        'width': 64}],
#      'name': 'Click Clack',
#      'release_date': '2019-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:0YcdHiYam184WYu39rev9k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ztOXfl03SlHkzRIsrvWmX'},
#       'href': 'https://api.spotify.com/v1/artists/4ztOXfl03SlHkzRIsrvWmX',
#       'id': '4ztOXfl03SlHkzRIsrvWmX',
#       'name': 'Guustavv',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ztOXfl03SlHkzRIsrvWmX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2MGL4XU2LCJC47c7VvSwuE'},
#       'href': 'https://api.spotify.com/v1/artists/2MGL4XU2LCJC47c7VvSwuE',
#       'id': '2MGL4XU2LCJC47c7VvSwuE',
#       'name': 'Jobii',
#       'type': 'artist',
#       'uri': 'spotify:artist:2MGL4XU2LCJC47c7VvSwuE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 118678,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5Q51900827'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3K6z3cqLgxKoBXb3O3jofb'},
#     'href': 'https://api.spotify.com/v1/tracks/3K6z3cqLgxKoBXb3O3jofb',
#     'id': '3K6z3cqLgxKoBXb3O3jofb',
#     'is_local': False,
#     'name': 'Acoustick',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/182d17516334245f182c4b5bd100a840a98c148f?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3K6z3cqLgxKoBXb3O3jofb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2y9j8qUwBMGPYPQJJxmYzD'},
#        'href': 'https://api.spotify.com/v1/artists/2y9j8qUwBMGPYPQJJxmYzD',
#        'id': '2y9j8qUwBMGPYPQJJxmYzD',
#        'name': 'Anna Clendening',
#        'type': 'artist',
#        'uri': 'spotify:artist:2y9j8qUwBMGPYPQJJxmYzD'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5vFQw6vOWYH9SaYVbSY9to'},
#      'href': 'https://api.spotify.com/v1/albums/5vFQw6vOWYH9SaYVbSY9to',
#      'id': '5vFQw6vOWYH9SaYVbSY9to',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734668bf5b0aedd4e72daed553',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024668bf5b0aedd4e72daed553',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514668bf5b0aedd4e72daed553',
#        'width': 64}],
#      'name': 'Boys Like You (Acoustic)',
#      'release_date': '2017-04-28',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5vFQw6vOWYH9SaYVbSY9to'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2y9j8qUwBMGPYPQJJxmYzD'},
#       'href': 'https://api.spotify.com/v1/artists/2y9j8qUwBMGPYPQJJxmYzD',
#       'id': '2y9j8qUwBMGPYPQJJxmYzD',
#       'name': 'Anna Clendening',
#       'type': 'artist',
#       'uri': 'spotify:artist:2y9j8qUwBMGPYPQJJxmYzD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 238576,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADA1781764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/51xRMJFRBrW9C1RI1qW4S0'},
#     'href': 'https://api.spotify.com/v1/tracks/51xRMJFRBrW9C1RI1qW4S0',
#     'id': '51xRMJFRBrW9C1RI1qW4S0',
#     'is_local': False,
#     'name': 'Boys Like You - Acoustic',
#     'popularity': 73,
#     'preview_url': 'https://p.scdn.co/mp3-preview/75e58a824cdd8cb48fa2f8c0b52428e8f4438f6f?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:51xRMJFRBrW9C1RI1qW4S0'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#        'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#        'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#        'name': 'Giveon',
#        'type': 'artist',
#        'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7pfQDManhpjhxwqps9cveA'},
#      'href': 'https://api.spotify.com/v1/albums/7pfQDManhpjhxwqps9cveA',
#      'id': '7pfQDManhpjhxwqps9cveA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730043fb835eab4610758979a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020043fb835eab4610758979a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510043fb835eab4610758979a3',
#        'width': 64}],
#      'name': 'Spotify Singles',
#      'release_date': '2020-08-28',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7pfQDManhpjhxwqps9cveA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4fxd5Ee7UefO4CUXgwJ7IP'},
#       'href': 'https://api.spotify.com/v1/artists/4fxd5Ee7UefO4CUXgwJ7IP',
#       'id': '4fxd5Ee7UefO4CUXgwJ7IP',
#       'name': 'Giveon',
#       'type': 'artist',
#       'uri': 'spotify:artist:4fxd5Ee7UefO4CUXgwJ7IP'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 185223,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM12005044'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0qXu4pFQSIwkfTUgkE6WzF'},
#     'href': 'https://api.spotify.com/v1/tracks/0qXu4pFQSIwkfTUgkE6WzF',
#     'id': '0qXu4pFQSIwkfTUgkE6WzF',
#     'is_local': False,
#     'name': 'LIKE I WANT YOU - Acoustic',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d678db57b056b29b489578fa1f1d3098b11b431?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0qXu4pFQSIwkfTUgkE6WzF'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#        'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#        'id': '2wY79sveU1sp5g7SokKOiI',
#        'name': 'Sam Smith',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6xMjjKuAngFJw7oh0lsfG8'},
#      'href': 'https://api.spotify.com/v1/albums/6xMjjKuAngFJw7oh0lsfG8',
#      'id': '6xMjjKuAngFJw7oh0lsfG8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273339dbb81685ceb1889b2b65e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02339dbb81685ceb1889b2b65e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851339dbb81685ceb1889b2b65e',
#        'width': 64}],
#      'name': 'Diamonds (Acoustic)',
#      'release_date': '2020-10-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6xMjjKuAngFJw7oh0lsfG8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2wY79sveU1sp5g7SokKOiI'},
#       'href': 'https://api.spotify.com/v1/artists/2wY79sveU1sp5g7SokKOiI',
#       'id': '2wY79sveU1sp5g7SokKOiI',
#       'name': 'Sam Smith',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wY79sveU1sp5g7SokKOiI'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 194541,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72004933'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4y8OZW2dyWRobsi2w0C64W'},
#     'href': 'https://api.spotify.com/v1/tracks/4y8OZW2dyWRobsi2w0C64W',
#     'id': '4y8OZW2dyWRobsi2w0C64W',
#     'is_local': False,
#     'name': 'Diamonds - Acoustic',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4y8OZW2dyWRobsi2w0C64W'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#        'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#        'id': '2h93pZq0e7k5yf4dywlkpM',
#        'name': 'Frank Ocean',
#        'type': 'artist',
#        'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0FAWfXvd58Rm2VUSZMF8pr'},
#      'href': 'https://api.spotify.com/v1/albums/0FAWfXvd58Rm2VUSZMF8pr',
#      'id': '0FAWfXvd58Rm2VUSZMF8pr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27335d8be841e9f7f777fbca446',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0235d8be841e9f7f777fbca446',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485135d8be841e9f7f777fbca446',
#        'width': 64}],
#      'name': 'Cayendo (Side A - Acoustic)',
#      'release_date': '2020-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0FAWfXvd58Rm2VUSZMF8pr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#       'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#       'id': '2h93pZq0e7k5yf4dywlkpM',
#       'name': 'Frank Ocean',
#       'type': 'artist',
#       'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 202200,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1921622'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/72794Eag03xdy7TO0KNuid'},
#     'href': 'https://api.spotify.com/v1/tracks/72794Eag03xdy7TO0KNuid',
#     'id': '72794Eag03xdy7TO0KNuid',
#     'is_local': False,
#     'name': 'Cayendo (Side A - Acoustic)',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c02a27fe9516ac43ebb7ef9aefd7c6d361385424?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:72794Eag03xdy7TO0KNuid'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ShZZUjkbXCjhwrb18BA8I'},
#        'href': 'https://api.spotify.com/v1/artists/1ShZZUjkbXCjhwrb18BA8I',
#        'id': '1ShZZUjkbXCjhwrb18BA8I',
#        'name': 'Bryce Vine',
#        'type': 'artist',
#        'uri': 'spotify:artist:1ShZZUjkbXCjhwrb18BA8I'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UfIYmCJf5pvhiaYH8X0fK'},
#      'href': 'https://api.spotify.com/v1/albums/2UfIYmCJf5pvhiaYH8X0fK',
#      'id': '2UfIYmCJf5pvhiaYH8X0fK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738f78bfa38964ef792d525ada',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028f78bfa38964ef792d525ada',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518f78bfa38964ef792d525ada',
#        'width': 64}],
#      'name': 'La La Land EP',
#      'release_date': '2019-07-05',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:2UfIYmCJf5pvhiaYH8X0fK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ShZZUjkbXCjhwrb18BA8I'},
#       'href': 'https://api.spotify.com/v1/artists/1ShZZUjkbXCjhwrb18BA8I',
#       'id': '1ShZZUjkbXCjhwrb18BA8I',
#       'name': 'Bryce Vine',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ShZZUjkbXCjhwrb18BA8I'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 137195,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11901204'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1sMi8ywnrNKysixM34zH9W'},
#     'href': 'https://api.spotify.com/v1/tracks/1sMi8ywnrNKysixM34zH9W',
#     'id': '1sMi8ywnrNKysixM34zH9W',
#     'is_local': False,
#     'name': 'La La Land - Acoustic',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f979ab84c9c5dfed5d2da7401891b1ffa5ef14e5?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1sMi8ywnrNKysixM34zH9W'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kCcBybjl3SAtIcwdWpUe3'},
#        'href': 'https://api.spotify.com/v1/artists/2kCcBybjl3SAtIcwdWpUe3',
#        'id': '2kCcBybjl3SAtIcwdWpUe3',
#        'name': 'Lil Peep',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kCcBybjl3SAtIcwdWpUe3'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1r1Xt6oUnY3VMYbQb1U7CO'},
#      'href': 'https://api.spotify.com/v1/albums/1r1Xt6oUnY3VMYbQb1U7CO',
#      'id': '1r1Xt6oUnY3VMYbQb1U7CO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c73bd9b0e34b067d7d3bd7b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c73bd9b0e34b067d7d3bd7b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c73bd9b0e34b067d7d3bd7b9',
#        'width': 64}],
#      'name': "EVERYBODY'S EVERYTHING",
#      'release_date': '2019-11-15',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:1r1Xt6oUnY3VMYbQb1U7CO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kCcBybjl3SAtIcwdWpUe3'},
#       'href': 'https://api.spotify.com/v1/artists/2kCcBybjl3SAtIcwdWpUe3',
#       'id': '2kCcBybjl3SAtIcwdWpUe3',
#       'name': 'Lil Peep',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kCcBybjl3SAtIcwdWpUe3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5g63iWaMJ2UrkZMkCC8dMi'},
#       'href': 'https://api.spotify.com/v1/artists/5g63iWaMJ2UrkZMkCC8dMi',
#       'id': '5g63iWaMJ2UrkZMkCC8dMi',
#       'name': 'Lil Tracy',
#       'type': 'artist',
#       'uri': 'spotify:artist:5g63iWaMJ2UrkZMkCC8dMi'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 118400,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQX91903114'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5Am6tsnSF2olM1bPpOdZRu'},
#     'href': 'https://api.spotify.com/v1/tracks/5Am6tsnSF2olM1bPpOdZRu',
#     'id': '5Am6tsnSF2olM1bPpOdZRu',
#     'is_local': False,
#     'name': 'walk away as the door slams - acoustic',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2e9544159c861bf681c9cadaa49bc7edb2500040?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:5Am6tsnSF2olM1bPpOdZRu'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z5WFjZAIYejWy0NI5lv4T'},
#        'href': 'https://api.spotify.com/v1/artists/7z5WFjZAIYejWy0NI5lv4T',
#        'id': '7z5WFjZAIYejWy0NI5lv4T',
#        'name': 'Dan + Shay',
#        'type': 'artist',
#        'uri': 'spotify:artist:7z5WFjZAIYejWy0NI5lv4T'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4hX3KKNZn3WHQIUNnSUyCc'},
#      'href': 'https://api.spotify.com/v1/albums/4hX3KKNZn3WHQIUNnSUyCc',
#      'id': '4hX3KKNZn3WHQIUNnSUyCc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736d6381b33e79cf8f8c50e4d6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026d6381b33e79cf8f8c50e4d6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516d6381b33e79cf8f8c50e4d6',
#        'width': 64}],
#      'name': 'I Should Probably Go To Bed (Acoustic)',
#      'release_date': '2020-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:4hX3KKNZn3WHQIUNnSUyCc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7z5WFjZAIYejWy0NI5lv4T'},
#       'href': 'https://api.spotify.com/v1/artists/7z5WFjZAIYejWy0NI5lv4T',
#       'id': '7z5WFjZAIYejWy0NI5lv4T',
#       'name': 'Dan + Shay',
#       'type': 'artist',
#       'uri': 'spotify:artist:7z5WFjZAIYejWy0NI5lv4T'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 177066,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB12003927'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3PUYUmxOlVtAEUMKuoT7T1'},
#     'href': 'https://api.spotify.com/v1/tracks/3PUYUmxOlVtAEUMKuoT7T1',
#     'id': '3PUYUmxOlVtAEUMKuoT7T1',
#     'is_local': False,
#     'name': 'I Should Probably Go To Bed - Acoustic',
# ...
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:4VuKGQiCzE5BdSdvp6Hjoh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#        'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#        'id': '2h93pZq0e7k5yf4dywlkpM',
#        'name': 'Frank Ocean',
#        'type': 'artist',
#        'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XPUXLAWXqM3uWMTucItjd'},
#      'href': 'https://api.spotify.com/v1/albums/4XPUXLAWXqM3uWMTucItjd',
#      'id': '4XPUXLAWXqM3uWMTucItjd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27367136d7919a1dc6a51ce3daf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0267136d7919a1dc6a51ce3daf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485167136d7919a1dc6a51ce3daf',
#        'width': 64}],
#      'name': 'Dear April (Side A - Acoustic)',
#      'release_date': '2020-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4XPUXLAWXqM3uWMTucItjd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#       'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#       'id': '2h93pZq0e7k5yf4dywlkpM',
#       'name': 'Frank Ocean',
#       'type': 'artist',
#       'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231040,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S1921625'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/62ljuuXo0zrcrtJnnOhfxT'},
#     'href': 'https://api.spotify.com/v1/tracks/62ljuuXo0zrcrtJnnOhfxT',
#     'id': '62ljuuXo0zrcrtJnnOhfxT',
#     'is_local': False,
#     'name': 'Dear April (Side A - Acoustic)',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ccf40d0fc2ee869d81e85a43419f0506dfbb67d1?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:62ljuuXo0zrcrtJnnOhfxT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0euMFLL3AIR9U21dCM0Jbx'},
#        'href': 'https://api.spotify.com/v1/artists/0euMFLL3AIR9U21dCM0Jbx',
#        'id': '0euMFLL3AIR9U21dCM0Jbx',
#        'name': 'Lillie-May Bonner',
#        'type': 'artist',
#        'uri': 'spotify:artist:0euMFLL3AIR9U21dCM0Jbx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/25SD5OPLxjD5MPd7KRyPtE'},
#      'href': 'https://api.spotify.com/v1/albums/25SD5OPLxjD5MPd7KRyPtE',
#      'id': '25SD5OPLxjD5MPd7KRyPtE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e5a612bbe159966ddcef66bd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e5a612bbe159966ddcef66bd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e5a612bbe159966ddcef66bd',
#        'width': 64}],
#      'name': 'Dancing Queen',
#      'release_date': '2020-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:25SD5OPLxjD5MPd7KRyPtE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0euMFLL3AIR9U21dCM0Jbx'},
#       'href': 'https://api.spotify.com/v1/artists/0euMFLL3AIR9U21dCM0Jbx',
#       'id': '0euMFLL3AIR9U21dCM0Jbx',
#       'name': 'Lillie-May Bonner',
#       'type': 'artist',
#       'uri': 'spotify:artist:0euMFLL3AIR9U21dCM0Jbx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 144404,
#     'explicit': False,
#     'external_ids': {'isrc': 'ESA011859140'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2JIrigmO9zwu8KwXI8WVrS'},
#     'href': 'https://api.spotify.com/v1/tracks/2JIrigmO9zwu8KwXI8WVrS',
#     'id': '2JIrigmO9zwu8KwXI8WVrS',
#     'is_local': False,
#     'name': 'Acoustic Drugs',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8e8bfcda0e83b85e6726e9300c6ba6d85a4b9a3d?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2JIrigmO9zwu8KwXI8WVrS'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20DZAfCuP1TKZl5KcY7z3Q'},
#        'href': 'https://api.spotify.com/v1/artists/20DZAfCuP1TKZl5KcY7z3Q',
#        'id': '20DZAfCuP1TKZl5KcY7z3Q',
#        'name': 'SLANDER',
#        'type': 'artist',
#        'uri': 'spotify:artist:20DZAfCuP1TKZl5KcY7z3Q'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6d0ZjIp5L7Ygy2l02HskRX'},
#        'href': 'https://api.spotify.com/v1/artists/6d0ZjIp5L7Ygy2l02HskRX',
#        'id': '6d0ZjIp5L7Ygy2l02HskRX',
#        'name': 'Dylan Matthew',
#        'type': 'artist',
#        'uri': 'spotify:artist:6d0ZjIp5L7Ygy2l02HskRX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4sFNNIc9t1SS1FnuVKXR3J'},
#      'href': 'https://api.spotify.com/v1/albums/4sFNNIc9t1SS1FnuVKXR3J',
#      'id': '4sFNNIc9t1SS1FnuVKXR3J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733892a2a2c261629f34bb5536',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023892a2a2c261629f34bb5536',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513892a2a2c261629f34bb5536',
#        'width': 64}],
#      'name': 'Love Is Gone (Acoustic)',
#      'release_date': '2019-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4sFNNIc9t1SS1FnuVKXR3J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20DZAfCuP1TKZl5KcY7z3Q'},
#       'href': 'https://api.spotify.com/v1/artists/20DZAfCuP1TKZl5KcY7z3Q',
#       'id': '20DZAfCuP1TKZl5KcY7z3Q',
#       'name': 'SLANDER',
#       'type': 'artist',
#       'uri': 'spotify:artist:20DZAfCuP1TKZl5KcY7z3Q'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6d0ZjIp5L7Ygy2l02HskRX'},
#       'href': 'https://api.spotify.com/v1/artists/6d0ZjIp5L7Ygy2l02HskRX',
#       'id': '6d0ZjIp5L7Ygy2l02HskRX',
#       'name': 'Dylan Matthew',
#       'type': 'artist',
#       'uri': 'spotify:artist:6d0ZjIp5L7Ygy2l02HskRX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176971,
#     'explicit': False,
#     'external_ids': {'isrc': 'CA5KR1969481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7F1CiKqrY44kh5cDqwHOnx'},
#     'href': 'https://api.spotify.com/v1/tracks/7F1CiKqrY44kh5cDqwHOnx',
#     'id': '7F1CiKqrY44kh5cDqwHOnx',
#     'is_local': False,
#     'name': 'Love Is Gone - Acoustic',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dae244cbe5d7eb8c62859fe5bbbf89479e4e542e?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7F1CiKqrY44kh5cDqwHOnx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t28BP42x2axFnqOOMg3CM'},
#        'href': 'https://api.spotify.com/v1/artists/5t28BP42x2axFnqOOMg3CM',
#        'id': '5t28BP42x2axFnqOOMg3CM',
#        'name': 'Five Finger Death Punch',
#        'type': 'artist',
#        'uri': 'spotify:artist:5t28BP42x2axFnqOOMg3CM'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1a1WAQEoebVlvCWng0k3fG'},
#      'href': 'https://api.spotify.com/v1/albums/1a1WAQEoebVlvCWng0k3fG',
#      'id': '1a1WAQEoebVlvCWng0k3fG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738b4b46b28175fc4726729c17',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028b4b46b28175fc4726729c17',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518b4b46b28175fc4726729c17',
#        'width': 64}],
#      'name': 'A Decade of Destruction, Vol.2',
#      'release_date': '2020-10-09',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1a1WAQEoebVlvCWng0k3fG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5t28BP42x2axFnqOOMg3CM'},
#       'href': 'https://api.spotify.com/v1/artists/5t28BP42x2axFnqOOMg3CM',
#       'id': '5t28BP42x2axFnqOOMg3CM',
#       'name': 'Five Finger Death Punch',
#       'type': 'artist',
#       'uri': 'spotify:artist:5t28BP42x2axFnqOOMg3CM'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 269787,
#     'explicit': False,
#     'external_ids': {'isrc': 'US5Z52000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7t29uSa0HdOApjR9uCvwAz'},
#     'href': 'https://api.spotify.com/v1/tracks/7t29uSa0HdOApjR9uCvwAz',
#     'id': '7t29uSa0HdOApjR9uCvwAz',
#     'is_local': False,
#     'name': 'Wrong Side of Heaven (Acoustic)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4b7ef354e1c4d6216ce0e565b2c55b1703c6d81c?cid=61571ab2d97c41c79ef2c934842244f6',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:7t29uSa0HdOApjR9uCvwAz'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=acoustic&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 100008}}
