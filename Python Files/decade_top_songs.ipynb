# %%
import json
import requests
import datetime 
import base64

# %%
from config import client_id
from config import client_secret

# %%
from __my_spotify import SpotifyAPI

# %%
import pandas as pd

# %%
from urllib.parse import urlencode

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.perform_auth()
# Out:
# True

# %%
client_access_token = client.access_token

# %%
csv_path = "../Resources/top_songs_of_2010_decade.csv"

# %%
decade_top_songs_df = pd.read_csv(csv_path, encoding='cp1252')

# %%
del decade_top_songs_df["Unnamed: 0"]
decade_top_songs_df.head()
# Out:
#                   title      artist        top genre  year  bpm  nrgy  dnce  \
# 0      Hey, Soul Sister       Train       neo mellow  2010   97    89    67
# 1  Love The Way You Lie      Eminem  detroit hip hop  2010   87    93    75
# 2               TiK ToK       Kesha        dance pop  2010  120    84    76
# 3           Bad Romance   Lady Gaga        dance pop  2010  119    92    70
# 4  Just the Way You Are  Bruno Mars              pop  2010  109    84    64
#
#    dB  live  val  dur  acous  spch  pop
# 0  -4     8   80  217     19     4   83
# 1  -5    52   64  263     24    23   82
# 2  -3    29   71  200     10    14   80
# 3  -4     8   71  295      0     4   79
# 4  -5     9   43  221      2     4   78

# %%
song_title_list = decade_top_songs_df['title'].tolist()

# %%
# Search API 

for song in song_title_list:
    headers = {
        "Authorization" : f"Bearer {client_access_token}"
    }

    endpoint = "https://api.spotify.com/v1/search?"

    data = urlencode({"q" : song,
                      "type" : "track", 
                      "limit" : 1
                     })

    lookup_url = f"{endpoint}{data}"

    response = requests.get(lookup_url, headers = headers).json()

    print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "tracks": {
#         "href": "https://api.spotify.com/v1/search?query=Hey%2C+Soul+Sister&type=track&offset=0&limit=1",
#         "items": [
#             {
#                 "album": {
#                     "album_type": "album",
#                     "artists": [
#                         {
#                             "external_urls": {
#                                 "spotify": "https://open.spotify.com/artist/3FUY2gzHeIiaesXtOAdB7A"
#                             },
#                             "href": "https://api.spotify.com/v1/artists/3FUY2gzHeIiaesXtOAdB7A",
#                             "id": "3FUY2gzHeIiaesXtOAdB7A",
#                             "name": "Train",
#                             "type": "artist",
#                             "uri": "spotify:artist:3FUY2gzHeIiaesXtOAdB7A"
#                         }
#                     ],
#                     "available_markets": [
#                         "AD",
#                         "AE",
# ...
